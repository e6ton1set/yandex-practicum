# %% [markdown]
# # Дашборд "Статистика платежеспособности"

# %% [markdown]
# Готовый дашборд, дополняющий интерактивной визулизацией проект [solvency_statistics](https://github.com/e6ton1set/yandex-practicum/blob/master/projects/solvency_statistics.ipynb)
